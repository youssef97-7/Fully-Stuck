# %% [markdown]
# # HTML Template Patch
#
# This notebook updates Django HTML templates to:
#
# - Add `{% load static %}`
# - Convert CSS `href` to `{% static %}` paths
# - Convert local scripts to `{% static %}`
# - Replace raw file-based links with Django named URL paths
# - Insert `{% csrf_token %}` into forms
